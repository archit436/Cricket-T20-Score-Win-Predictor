# %%
# Start by importing the relevant libraries.
import pandas as pd
import pickle
import numpy as np
import warnings
warnings.simplefilter(action='ignore', category=pd.errors.SettingWithCopyWarning)

# %%
# load delivery dataframe from dataset exported under data_extraction
df = pickle.load(open('dataset_level2_first_innings.pkl', 'rb'))

# %% [markdown]
# From here on, we will work on modifying this DataFrame to contain data for the 8 features we want to use for the developement of our model. These features are as follows: batting team, bowling team, current score, wickets left, current run rate, city, balls left, last five overs (runs scored)

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              1    Australia    Sri Lanka   0.1     0                0
# 1              1    Australia    Sri Lanka   0.2     0                0
# 2              1    Australia    Sri Lanka   0.3     1                0
# 3              1    Australia    Sri Lanka   0.4     2                0
# 4              1    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       963    Sri Lanka    Australia  19.3     1                0
# 115321       963    Sri Lanka    Australia  19.4     0                0
# 115322       963    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       963    Sri Lanka    Australia  19.6     2                0
# 115324       963    Sri Lanka    Australia  19.7     1                0
#
#            city                     venue
# 0           NaN  Melbourne Cricket Ground
# 1           NaN  Melbourne Cricket Ground
# 2           NaN  Melbourne Cricket Ground
# 3           NaN  Melbourne Cricket Ground
# 4           NaN  Melbourne Cricket Ground
# ...         ...                       ...
# 115320  Colombo       R Premadasa Stadium
# 115321  Colombo       R Premadasa Stadium
# 115322  Colombo       R Premadasa Stadium
# 115323  Colombo       R Premadasa Stadium
# 115324  Colombo       R Premadasa Stadium
#
# [75817 rows x 8 columns]

# %% [markdown]
# 2/8 features have been extracted.

# %%
# Start by focusing on the city column.
# Count the number of NaN values in the city column.
df['city'].isnull().sum()
# Out:
# 12360

# %%
# For the line items with NaN city values, look at the venue values.
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# venue
# Dubai International Cricket Stadium        3425
# Harare Sports Club                         2731
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1453
# Sharjah Cricket Stadium                     757
# Sydney Cricket Ground                       749
# Adelaide Oval                               498
# Rawalpindi Cricket Stadium                  368
# Sylhet International Cricket Stadium        128
# Sylhet Stadium                              121
# Carrara Oval                                 64
# Name: count, dtype: int64

# %%
# The output above indicates that for NaN values in the city column, we can use the first word from the values 
# of the venue column.
# We create a condition using np.where() to assign values where city column value is NaN
# These values are outputted to an array called cities that can then update the DataFrame.
cities = np.where(df['city'].isnull(), df['venue'].str.split().apply(lambda x:x[0]), df['city'])
df['city'] = cities

# %%
# Check all columns for any NaN values.
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
# Remove the Venue column since it is not needed anymore = not a feature, redundant with city.
df.drop(columns = ['venue'], inplace = True)

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              1    Australia    Sri Lanka   0.1     0                0
# 1              1    Australia    Sri Lanka   0.2     0                0
# 2              1    Australia    Sri Lanka   0.3     1                0
# 3              1    Australia    Sri Lanka   0.4     2                0
# 4              1    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       963    Sri Lanka    Australia  19.3     1                0
# 115321       963    Sri Lanka    Australia  19.4     0                0
# 115322       963    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       963    Sri Lanka    Australia  19.6     2                0
# 115324       963    Sri Lanka    Australia  19.7     1                0
#
#              city
# 0       Melbourne
# 1       Melbourne
# 2       Melbourne
# 3       Melbourne
# 4       Melbourne
# ...           ...
# 115320    Colombo
# 115321    Colombo
# 115322    Colombo
# 115323    Colombo
# 115324    Colombo
#
# [75817 rows x 7 columns]

# %%
# For city column, we also want to trim the data to include cities for which enough data 
# is available to optimally train the model. We define a conditon of atlest 5 matches.
eligible_cities = df['city'].value_counts()[df['city'].value_counts() > 600].index.tolist()
df = df[df['city'].isin(eligible_cities)]

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              1    Australia    Sri Lanka   0.1     0                0
# 1              1    Australia    Sri Lanka   0.2     0                0
# 2              1    Australia    Sri Lanka   0.3     1                0
# 3              1    Australia    Sri Lanka   0.4     2                0
# 4              1    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       963    Sri Lanka    Australia  19.3     1                0
# 115321       963    Sri Lanka    Australia  19.4     0                0
# 115322       963    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       963    Sri Lanka    Australia  19.6     2                0
# 115324       963    Sri Lanka    Australia  19.7     1                0
#
#              city
# 0       Melbourne
# 1       Melbourne
# 2       Melbourne
# 3       Melbourne
# 4       Melbourne
# ...           ...
# 115320    Colombo
# 115321    Colombo
# 115322    Colombo
# 115323    Colombo
# 115324    Colombo
#
# [60018 rows x 7 columns]

# %% [markdown]
# 3/8 features have been extracted.

# %%
# Now we focus on the current score feature. Currently, our dataframe only has runs conceded
# for every delivery.
# We use groupby here which is an operation to split a python object, apply a funciton and combine
# the results in another python object that we can then run operations on.
df.loc[:,'current_score'] = df.groupby('match_id')['runs'].cumsum()

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              1    Australia    Sri Lanka   0.1     0                0
# 1              1    Australia    Sri Lanka   0.2     0                0
# 2              1    Australia    Sri Lanka   0.3     1                0
# 3              1    Australia    Sri Lanka   0.4     2                0
# 4              1    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       963    Sri Lanka    Australia  19.3     1                0
# 115321       963    Sri Lanka    Australia  19.4     0                0
# 115322       963    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       963    Sri Lanka    Australia  19.6     2                0
# 115324       963    Sri Lanka    Australia  19.7     1                0
#
#              city  current_score
# 0       Melbourne              0
# 1       Melbourne              0
# 2       Melbourne              1
# 3       Melbourne              3
# 4       Melbourne              3
# ...           ...            ...
# 115320    Colombo            125
# 115321    Colombo            125
# 115322    Colombo            125
# 115323    Colombo            127
# 115324    Colombo            128
#
# [60018 rows x 8 columns]

# %% [markdown]
# 4/8 features have been extracted.

# %%
# Now we focus on the balls left feature.
# Start by splitting the data in 'ball' column into over and ball no.
overs = df['ball'].apply(lambda x:str(x).split(".")[0])
ball_no = df['ball'].apply(lambda x:str(x).split(".")[1])
# We can use this computed data to now compute the balls left for every delivery line item.
balls_bowled = (overs.astype('int')*6) + ball_no.astype('int') # No need to account for extras.
balls_left = 120 - balls_bowled
# Add this to the DataFrame
df.loc[:, 'balls_left'] = balls_left.apply(lambda x:0 if x<0 else x)
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              1    Australia    Sri Lanka   0.1     0                0
# 1              1    Australia    Sri Lanka   0.2     0                0
# 2              1    Australia    Sri Lanka   0.3     1                0
# 3              1    Australia    Sri Lanka   0.4     2                0
# 4              1    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       963    Sri Lanka    Australia  19.3     1                0
# 115321       963    Sri Lanka    Australia  19.4     0                0
# 115322       963    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       963    Sri Lanka    Australia  19.6     2                0
# 115324       963    Sri Lanka    Australia  19.7     1                0
#
#              city  current_score  balls_left
# 0       Melbourne              0         119
# 1       Melbourne              0         118
# 2       Melbourne              1         117
# 3       Melbourne              3         116
# 4       Melbourne              3         115
# ...           ...            ...         ...
# 115320    Colombo            125           3
# 115321    Colombo            125           2
# 115322    Colombo            125           1
# 115323    Colombo            127           0
# 115324    Colombo            128           0
#
# [60018 rows x 9 columns]

# %% [markdown]
# 5/8 features have been extracted.

# %%
# Now we find the wickets left feature from the data.
# Start by creating a list of 1 and 0 to represent whether a wicket was taken on a ball
# Then group data by matches and find the sum
df.loc[:, 'wickets_left'] = df['player_dismissed'].apply(lambda x:0 if x == '0' else 1)
df.loc[:, 'wickets_left'] = df['wickets_left'].astype('int')
df.loc[:, 'wickets_left'] = df.groupby('match_id')['wickets_left'].cumsum()
df.loc[:, 'wickets_left'] = 10 - df['wickets_left']
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              1    Australia    Sri Lanka   0.1     0                0
# 1              1    Australia    Sri Lanka   0.2     0                0
# 2              1    Australia    Sri Lanka   0.3     1                0
# 3              1    Australia    Sri Lanka   0.4     2                0
# 4              1    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       963    Sri Lanka    Australia  19.3     1                0
# 115321       963    Sri Lanka    Australia  19.4     0                0
# 115322       963    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       963    Sri Lanka    Australia  19.6     2                0
# 115324       963    Sri Lanka    Australia  19.7     1                0
#
#              city  current_score  balls_left  wickets_left
# 0       Melbourne              0         119            10
# 1       Melbourne              0         118            10
# 2       Melbourne              1         117            10
# 3       Melbourne              3         116            10
# 4       Melbourne              3         115            10
# ...           ...            ...         ...           ...
# 115320    Colombo            125           3             2
# 115321    Colombo            125           2             2
# 115322    Colombo            125           1             1
# 115323    Colombo            127           0             1
# 115324    Colombo            128           0             1
#
# [60018 rows x 10 columns]

# %% [markdown]
# 6/8 features extracted.

# %%
# Now we focus on the current run rate feature.
df.loc[:, 'crr'] = (df['current_score']*6)/balls_bowled
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              1    Australia    Sri Lanka   0.1     0                0
# 1              1    Australia    Sri Lanka   0.2     0                0
# 2              1    Australia    Sri Lanka   0.3     1                0
# 3              1    Australia    Sri Lanka   0.4     2                0
# 4              1    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       963    Sri Lanka    Australia  19.3     1                0
# 115321       963    Sri Lanka    Australia  19.4     0                0
# 115322       963    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       963    Sri Lanka    Australia  19.6     2                0
# 115324       963    Sri Lanka    Australia  19.7     1                0
#
#              city  current_score  balls_left  wickets_left       crr
# 0       Melbourne              0         119            10  0.000000
# 1       Melbourne              0         118            10  0.000000
# 2       Melbourne              1         117            10  2.000000
# 3       Melbourne              3         116            10  4.500000
# 4       Melbourne              3         115            10  3.600000
# ...           ...            ...         ...           ...       ...
# 115320    Colombo            125           3             2  6.410256
# 115321    Colombo            125           2             2  6.355932
# 115322    Colombo            125           1             1  6.302521
# 115323    Colombo            127           0             1  6.350000
# 115324    Colombo            128           0             1  6.347107
#
# [60018 rows x 11 columns]

# %% [markdown]
# 7/8 features extracted.

# %%
# The last feature is runs scored in last 5 overs.
# Group the delivery by matches.
groups = df.groupby('match_id')
# Get a list of all match ids to iterate through.
match_ids = df['match_id'].unique()
# Create a container to serve as a temp buffer for the values of last 5 overs.
last_five = []
# Iterate through each match
for id in match_ids:
    # Compute the values using a rolling window.
    last_five.extend(groups.get_group(id)['runs'].rolling(window = 30).sum().values.tolist())

# %%
# Add these values to the DataFrame
df.loc[:,'last_five'] = last_five

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              1    Australia    Sri Lanka   0.1     0                0
# 1              1    Australia    Sri Lanka   0.2     0                0
# 2              1    Australia    Sri Lanka   0.3     1                0
# 3              1    Australia    Sri Lanka   0.4     2                0
# 4              1    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       963    Sri Lanka    Australia  19.3     1                0
# 115321       963    Sri Lanka    Australia  19.4     0                0
# 115322       963    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       963    Sri Lanka    Australia  19.6     2                0
# 115324       963    Sri Lanka    Australia  19.7     1                0
#
#              city  current_score  balls_left  wickets_left       crr  \
# 0       Melbourne              0         119            10  0.000000
# 1       Melbourne              0         118            10  0.000000
# 2       Melbourne              1         117            10  2.000000
# 3       Melbourne              3         116            10  4.500000
# 4       Melbourne              3         115            10  3.600000
# ...           ...            ...         ...           ...       ...
# 115320    Colombo            125           3             2  6.410256
# 115321    Colombo            125           2             2  6.355932
# 115322    Colombo            125           1             1  6.302521
# 115323    Colombo            127           0             1  6.350000
# 115324    Colombo            128           0             1  6.347107
#
#         last_five
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 115320       32.0
# 115321       32.0
# 115322       32.0
# 115323       33.0
# 115324       32.0
#
# [60018 rows x 12 columns]

# %% [markdown]
# 8/8 features have been extracted.

# %%
# Now we move to the output of the model - the final score.
final_df = df.groupby('match_id')['runs'].sum().reset_index().merge(df, on = 'match_id')

# %%
final_df
# Out:
#        match_id  runs_x batting_team bowling_team  ball  runs_y  \
# 0             1     168    Australia    Sri Lanka   0.1       0
# 1             1     168    Australia    Sri Lanka   0.2       0
# 2             1     168    Australia    Sri Lanka   0.3       1
# 3             1     168    Australia    Sri Lanka   0.4       2
# 4             1     168    Australia    Sri Lanka   0.5       0
# ...         ...     ...          ...          ...   ...     ...
# 60013       963     128    Sri Lanka    Australia  19.3       1
# 60014       963     128    Sri Lanka    Australia  19.4       0
# 60015       963     128    Sri Lanka    Australia  19.5       0
# 60016       963     128    Sri Lanka    Australia  19.6       2
# 60017       963     128    Sri Lanka    Australia  19.7       1
#
#       player_dismissed       city  current_score  balls_left  wickets_left  \
# 0                    0  Melbourne              0         119            10
# 1                    0  Melbourne              0         118            10
# 2                    0  Melbourne              1         117            10
# 3                    0  Melbourne              3         116            10
# 4                    0  Melbourne              3         115            10
# ...                ...        ...            ...         ...           ...
# 60013                0    Colombo            125           3             2
# 60014                0    Colombo            125           2             2
# 60015      DM de Silva    Colombo            125           1             1
# 60016                0    Colombo            127           0             1
# 60017                0    Colombo            128           0             1
#
#             crr  last_five
# 0      0.000000        NaN
# 1      0.000000        NaN
# 2      2.000000        NaN
# 3      4.500000        NaN
# 4      3.600000        NaN
# ...         ...        ...
# 60013  6.410256       32.0
# 60014  6.355932       32.0
# 60015  6.302521       32.0
# 60016  6.350000       33.0
# 60017  6.347107       32.0
#
# [60018 rows x 13 columns]

# %%
# Further clean up final DataFrame to include only relevant features.
final_df = final_df[['batting_team', 'bowling_team', 'city', 'current_score', 'balls_left', 'wickets_left', 'crr', 'last_five', 'runs_x']]

# %%
final_df
# Out:
#       batting_team bowling_team       city  current_score  balls_left  \
# 0        Australia    Sri Lanka  Melbourne              0         119
# 1        Australia    Sri Lanka  Melbourne              0         118
# 2        Australia    Sri Lanka  Melbourne              1         117
# 3        Australia    Sri Lanka  Melbourne              3         116
# 4        Australia    Sri Lanka  Melbourne              3         115
# ...            ...          ...        ...            ...         ...
# 60013    Sri Lanka    Australia    Colombo            125           3
# 60014    Sri Lanka    Australia    Colombo            125           2
# 60015    Sri Lanka    Australia    Colombo            125           1
# 60016    Sri Lanka    Australia    Colombo            127           0
# 60017    Sri Lanka    Australia    Colombo            128           0
#
#        wickets_left       crr  last_five  runs_x
# 0                10  0.000000        NaN     168
# 1                10  0.000000        NaN     168
# 2                10  2.000000        NaN     168
# 3                10  4.500000        NaN     168
# 4                10  3.600000        NaN     168
# ...             ...       ...        ...     ...
# 60013             2  6.410256       32.0     128
# 60014             2  6.355932       32.0     128
# 60015             1  6.302521       32.0     128
# 60016             1  6.350000       33.0     128
# 60017             1  6.347107       32.0     128
#
# [60018 rows x 9 columns]

# %%
# Drop rows with NaN values in the last_five column.
final_df.dropna(inplace = True)

# %%
final_df
# Out:
#       batting_team bowling_team       city  current_score  balls_left  \
# 29       Australia    Sri Lanka  Melbourne             43          90
# 30       Australia    Sri Lanka  Melbourne             44          89
# 31       Australia    Sri Lanka  Melbourne             45          88
# 32       Australia    Sri Lanka  Melbourne             45          87
# 33       Australia    Sri Lanka  Melbourne             45          86
# ...            ...          ...        ...            ...         ...
# 60013    Sri Lanka    Australia    Colombo            125           3
# 60014    Sri Lanka    Australia    Colombo            125           2
# 60015    Sri Lanka    Australia    Colombo            125           1
# 60016    Sri Lanka    Australia    Colombo            127           0
# 60017    Sri Lanka    Australia    Colombo            128           0
#
#        wickets_left       crr  last_five  runs_x
# 29               10  8.600000       43.0     168
# 30               10  8.516129       44.0     168
# 31               10  8.437500       45.0     168
# 32               10  8.181818       44.0     168
# 33               10  7.941176       42.0     168
# ...             ...       ...        ...     ...
# 60013             2  6.410256       32.0     128
# 60014             2  6.355932       32.0     128
# 60015             1  6.302521       32.0     128
# 60016             1  6.350000       33.0     128
# 60017             1  6.347107       32.0     128
#
# [45732 rows x 9 columns]

# %%
# Shuffle the data to reduce chances of a bias.
final_df = final_df.sample(final_df.shape[0])

# %%
final_df
# Out:
#        batting_team bowling_team          city  current_score  balls_left  \
# 22713     Australia      England    Manchester             86          35
# 57953       England    Sri Lanka         Delhi            161           5
# 18502  South Africa        India  Johannesburg             31          86
# 36915   New Zealand     Zimbabwe        Harare             94          65
# 45449  South Africa    Australia     Centurion             90          26
# ...             ...          ...           ...            ...         ...
# 44562  South Africa    Sri Lanka    Hambantota            134           6
# 36899   New Zealand     Zimbabwe        Harare             55          81
# 8896   South Africa     Pakistan  Johannesburg            153           9
# 58659       England  West Indies       Kolkata            108          40
# 46933   New Zealand    Sri Lanka     Pallekele             93          33
#
#        wickets_left        crr  last_five  runs_x
# 22713             7   6.070588       30.0     145
# 57953             7   8.400000       64.0     171
# 18502             8   5.470588       29.0     126
# 36915            10  10.254545       52.0     187
# 45449             4   5.744681       22.0     128
# ...             ...        ...        ...     ...
# 44562             4   7.052632       43.0     145
# 36899            10   8.461538       37.0     187
# 8896              7   8.270270       53.0     188
# 58659             6   8.100000       60.0     155
# 46933             6   6.413793       37.0     142
#
# [45732 rows x 9 columns]

# %%
# Pickle dump the final DataFrame
import pickle
pickle.dump(final_df, open('dataset_level3_first_innings.pkl','wb'))
